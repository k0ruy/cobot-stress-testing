# %%
import os
import pickle
import neurokit2 as nk
import sensors_import_support as sis
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
import numpy as np

# %%
experiment_type = 'manual'
eda = pd.read_csv(Path("saved_data", f"eda_time_and_freq_features_{experiment_type}.csv"))

# %%
# Import questionnaires and subjects data
with open('questionnaires.pkl', 'rb') as f:
    subject_data = pickle.load(f)

subject_data

# %%
eda

# "EDA mean levels usually range between 2 and 20µS,
# and vary within a range between 1 and 3µS for different individuals" 
# then why is this mean negative?
# Out:
#       meanEda    stdEda   kurtEda   skewEda  meanDerivative  \
# 0   -1.228002  0.055869 -0.184438  0.210894   -1.243746e-06
# 1   -1.097556  0.048130 -0.401592 -0.196224    5.338369e-06
# 2   -0.853370  0.260728 -1.443673  0.475096    1.778707e-05
# 3   -0.494371  0.038116  1.589804 -0.449199    8.953475e-07
# 4   -0.322581  0.087861 -0.652999 -0.490274    7.342599e-06
# ..        ...       ...       ...       ...             ...
# 956 -0.140933  1.011737  2.610649 -0.026697   -3.152323e-05
# 957  0.009602  1.060937  2.664083 -0.024548   -2.354747e-05
# 958  0.136295  1.026345  2.909593 -0.066697   -3.008000e-05
# 959  0.278914  0.938954  3.367215  0.020613    9.532929e-05
# 960  0.383667  1.113823  2.684364 -0.056194   -9.798787e-06
#
#      meanNegativeDerivative      activity  mobility  complexity  peaksCount  \
# 0                 -0.020048     93.640339  0.484831    1.781909         6.0
# 1                 -0.010295     69.494093  0.333035    2.559317         8.0
# ...
